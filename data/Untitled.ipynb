# %%
import json

# %%
with open('western-europe.json', 'r') as f:
    geojson = json.load(f)

# %%
for feature in geojson['features']:
    name = feature['properties']['IOS_A3_EH']
# Out:
# {'type': 'Feature', 'properties': {'SOVEREIGNT': 'France', 'SOV_A3': 'FR1', 'LEVEL': 2, 'TYPE': 'Country', 'ADMIN': 'France', 'NAME': 'France', 'NAME_LONG': 'France', 'ABBREV': 'Fr.', 'POP_EST': 67106161, 'WIKIPEDIA': -99, 'ISO_A2': '-99', 'ISO_A3': '-99', 'ISO_A3_EH': 'FRA', 'ISO_N3': '250', 'UN_A3': '250', 'WB_A2': 'FR', 'WB_A3': 'FRA', 'CONTINENT': 'Europe', 'REGION_UN': 'Europe', 'SUBREGION': 'Western Europe'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-54.1115266969999, 2.114270443000066], [-54.134908, 2.11067332000006], [-54.14813716599994, 2.114394023000074], [-54.15738724899995, 2.121654562000046], [-54.18854813699994, 2.161316224000117], [-54.194490925999844, 2.163073222000094], [-54.210045532999885, 2.161574605000098], [-54.229785929999935, 2.157233785000116], [-54.246477416999966, 2.151601054000082], [-54.263789021999884, 2.148190410000055], [-54.31401851399991, 2.154856669000068], [-54.32285518499992, 2.157337138000045], [-54.33505082199994, 2.16390004500003
# ...
